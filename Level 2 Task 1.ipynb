# %%
import pandas as pd


df = pd.read_csv("Dataset.csv")

# %%
table_booking_percentage = (df['Has Table booking'].value_counts(normalize=True) * 100)
print("Percentage of Restaurants with Table Booking:\n")
print(table_booking_percentage)
# Out:
# Percentage of Restaurants with Table Booking:
#
# No     87.875615
# Yes    12.124385
# Name: Has Table booking, dtype: float64

# %%
online_delivery_percentage = (df['Has Online delivery'].value_counts(normalize=True) * 100)
print("\nPercentage of Restaurants with Online Delivery:\n")
print(online_delivery_percentage)
# Out:
# Percentage of Restaurants with Online Delivery:
#
# No     74.337766
# Yes    25.662234
# Name: Has Online delivery, dtype: float64

# %%
avg_rating_table_booking = df.groupby('Has Table booking')['Aggregate rating'].mean()

print("\nAverage Rating Comparison:\n")
print(avg_rating_table_booking)
# Out:
# Average Rating Comparison:
#
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %%
delivery_price_range = pd.crosstab(df['Price range'], df['Has Online delivery'])

print("\nOnline Delivery by Price Range:\n")
print(delivery_price_range)
# Out:
# Online Delivery by Price Range:
#
# Has Online delivery    No   Yes
# Price range
# 1                    3743   701
# 2                    1827  1286
# 3                     997   411
# 4                     533    53

# %%
delivery_price_range_percent = pd.crosstab(
    df['Price range'], 
    df['Has Online delivery'], 
    normalize='index'
) * 100

print("\nOnline Delivery Percentage by Price Range:\n")
print(delivery_price_range_percent)
# Out:
# Online Delivery Percentage by Price Range:
#
# Has Online delivery         No        Yes
# Price range
# 1                    84.225923  15.774077
# 2                    58.689367  41.310633
# 3                    70.809659  29.190341
# 4                    90.955631   9.044369
